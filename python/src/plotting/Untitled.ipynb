# %%
import config as cfg
from plot_cubic import plot_grain_boundary, plot_square, create_material, save_blender_fig, plot_all_grain_boundaries, plot_cubes_from_simulation_results, path_to_transparent_cube
from geometry.cubic import CubicLattice, CubicParticle

# %% [raw]
# face_lattice_coords = [.25, 0, 0]
# bond_lattice_coords = [1, 0, 0]
# lattice = CubicLattice(10, 10)
# material = create_material()
# plot_square(face_lattice_coords, bond_lattice_coords, lattice, material)
# save_blender_fig("test_fig.blend")

# %% [raw]
# face_lattice_coords = [0, 0.25, 0]
# bond_lattice_coords = [0, 1, 0]
# lattice = CubicLattice(10, 10)
# material = create_material()
# plot_square(face_lattice_coords, bond_lattice_coords, lattice, material)
# save_blender_fig("test_fig.blend")

# %% [raw]
# face_lattice_coords = [0, 0, -0.25]
# bond_lattice_coords = [0, 0, -1]
# lattice = CubicLattice(10, 10)
# material = create_material()
# plot_square(face_lattice_coords, bond_lattice_coords, lattice, material)
# save_blender_fig("test_fig.blend")

# %% [raw]
# import numpy as np
# lattice = CubicLattice(10, 10)
#
# site_1 = 0
# site_2_coords = np.array([0, 0, 9])
# site_2 = lattice.lattice_coords_to_lattice_site(*site_2_coords)
#
# orientation_1 = 0
# orientation_2 = 0
# boundary_contacts = [(i, j) for i in range(24) for j in range(24)]
# material = create_material()
# plot_grain_boundary(site_1, site_2, orientation_1, orientation_2, lattice, boundary_contacts, material)
# save_blender_fig("test_fig.blend")

# %%
from designs.cubic import HEDGEHOG_CONTACTS

# %%
struct_folder = "/Users/vincent/research/projects/23_frustratedSelfAssembly/camemberts3D/simulations/250128_cubicCamembertsHedgehog_test/notebook/data/hedgehog_camembert_crystal_-10.00_defect_-20.00_repel_10000.00/structures"
model_file = "/Users/vincent/research/projects/23_frustratedSelfAssembly/camemberts3D/simulations/250128_cubicCamembertsHedgehog_test/frusa_lattice_mc/input/model_params.json"
plot_all_grain_boundaries(struct_folder=struct_folder, model_file=model_file, boundary_contacts=HEDGEHOG_CONTACTS)
plot_cubes_from_simulation_results(struct_folder=struct_folder, model_file=model_file, path_to_cube=path_to_transparent_cube)
save_blender_fig("test_fig.blend")
# Out:
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/camemberts3D/simulations/250128_cubicCamembertsHedgehog_test/frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/camemberts3D/simulations/250128_cubicCamembertsHedgehog_test/frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/camemberts3D/simulations/250128_cubicCamembertsHedgehog_test/frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/camemberts3D/simulations/250128_cubicCamembertsHedgehog_test/frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# ...

# %%
save_blender_fig("test_fig.blend")
# Out:
# Info: Saved "test_fig.blend"

# %%
plot_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_
#
# NameError: name 'plot_' is not defined

# %%
site_2_coords.gg

# %%
s = set()

# %%
ss = set(s)
