# %%
import matplotlib.pyplot as plt
plt.ion()
import plotting.plot_tri as pt

# %%
pr = pt.ParticleRepresentation()

# %%
help(pr.plot_particle_outline)
# Out:
# Help on method plot_particle_outline in module plotting.plot_tri:
#
# plot_particle_outline(x_center_lattice: int, y_center_lattice: int, orientation: int, ax: matplotlib.axes._axes.Axes) -> None method of plotting.plot_tri.ParticleRepresentation instance
#     # V: I stopped before working on this function

# %%
fig, ax = plt.subplots(figsize = (10, 10))
pr.plot_particle_outline(0, 0, 0, ax)
pr.plot_particle_outline(1, 0, 0, ax)
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
# %matplotlib inline
plt.show()

# %%
# %gui qt

# %%
import numpy as np
np.tan(np.pi/6)
# Out:
# 0.5773502691896256

# %%
pr.lattice_to_cartesian(1, 0)
# Out:
# array([1., 0.])
