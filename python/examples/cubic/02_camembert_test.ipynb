# %% [markdown]
# # Making a cubic camembert
#
# The moonshot: I have designed a camembert contact map. Let's see if it actually works!

# %%
import numpy as np
from json_dump import *
import contact_utils as cu
import config as cfg
from pathlib import Path
from geometry.cubic import CubicGeometry
from plotting.plot_cubic import plot_cubes_from_simulation_results

# %%
### Key parameter: how we will name this run
run_name = "01_camembert_test"

### Define model parameters

model_params = {}

# ---------- LATTICE OPTIONS ----------

# Options:
# "chain", "square", "triangular", "cubic", "bcc", "fcc"
model_params["lattice_name"] = "cubic"

# Lattice dimensions
model_params["lx"] = 18
model_params["ly"] = 18  # Has to be 1 for chain
model_params["lz"] = 18  # Has to be 1 for square & triangular

# %%
# ---------- MODEL PARAMETERS ----------

# Number of particle types
model_params["n_types"] = 1

# Number of particles of each type
model_params["n_particles"] = [200]

# Couplings is its own beast. Should be gotten with the appropriate helper
# function.

# %% [markdown]
# ## Important note: for 3D particles, do not use the get_matrix and set_contact utils!
#
# A lot of face pairs are equivalent under rotation for cubes (e.g. (0, 0), (1, 3), (2, 2), (3, 1)).
# When using a full contact matrix and feeding it to the wrapper using `set_single_species_contacts`, if all the equivalent pairs don't
# have the same matrix coefficient, some of them will be overwritten by other values, and the contacts will be wrong.
#
# Better to do things the way they are done below

# %%
crystal_energy = -18.7
# crystal_energy = 0
# defect_energy = -10
defect_energy = crystal_energy / 0.5
repel_energy = 10000
# crystal_energy = repel_energy

# %%
get_opposite_face = CubicGeometry().get_opposite_face
# First, create a cmap_wrapper object with the appropriate number of particle types
cmap_wrapper = cu.ContactMapWrapper.cubic(
    n_types = model_params["n_types"], init_energy = repel_energy)

# Setting crystalline interactions
for i in range(3):
    face = 4 * i
    opposite_face = get_opposite_face(face)
    cmap_wrapper[face, opposite_face] = crystal_energy

# %%
# Setting camembert interactions

# First, let's tabulate the contacts along each circulation line
# of internal axes
contacts_Rplus = [
    (4, 13),
    (8, 13),
    (12, 17),
    (12, 23),
]

contacts_Gplus = [
    (0, 17),
    (8, 16),
    (12, 17),
    (16, 20)
]

contacts_Bplus = [
    (0, 21),
    (4, 22),
    (12, 23),
    (16,20)
]

contacts_Rminus = [
    (0, 9),
    (0, 17),
    (0, 21),
    (0, 7)
]

contacts_Gminus = [
    (4, 22),
    (4, 13),
    (4, 10),
    (0, 7),
]

contacts_Bminus = [
    (0, 9),
    (4, 10),
    (8, 13),
    (8, 16)
]

# %%
Rplus_flag = True
Gplus_flag = True
Bplus_flag = True

Rminus_flag = True
Gminus_flag = True
Bminus_flag = True

camembert_contacts = []
if Rplus_flag:
    camembert_contacts.extend(contacts_Rplus)
if Gplus_flag:
    camembert_contacts.extend(contacts_Gplus)
if Bplus_flag:
    camembert_contacts.extend(contacts_Bplus)
if Rminus_flag:
    camembert_contacts.extend(contacts_Rminus)
if Gminus_flag:
    camembert_contacts.extend(contacts_Gminus)
if Bminus_flag:
    camembert_contacts.extend(contacts_Bminus)


for contact in camembert_contacts:
    cmap_wrapper[contact] = defect_energy

# And process the couplings into flattened form
model_params["couplings"] = cmap_wrapper.get_formatted_couplings()

# %%
# Initialization option
model_params["initialize_option"] = "random"

# If "initialize_option" is set to "from_file", we must specify the location of
# the input file
# model_params["state_input"] = str(cfg.structures_path/"final_structure.dat")

# Options for average collection

model_params["state_av_option"] = True
model_params["e_av_option"] = True

if model_params["state_av_option"]:
    state_path = Path("./data/"+run_name+"/average_state")
    state_path.mkdir(parents = True, exist_ok = True)
    model_params["state_av_output"] =  str(state_path.resolve()) + "/"

if model_params["e_av_option"]:
    energy_path = Path("./data/"+run_name+"/average_energy")
    energy_path.mkdir(parents = True, exist_ok = True)
    model_params["e_av_output"] = str(energy_path.resolve())  + "/"

# %%
# Pick the probabilities of different moves. Has to sum to 1.
# Options:
""""
    "swap_empty_full",
    "swap_full_full",
    "rotate",
    "mutate",
    "rotate_and_swap_w_empty"
"""

moves_dict = {}
moves_dict["swap_empty_full"] = 1/3
moves_dict["rotate"] = 1/3
moves_dict["rotate_and_swap_w_empty"] = 1/3

model_params["move_probas"] = moves_dict

make_json_file(model_params, cfg.input_path/"model_params.json")

# %%
### Define mc parameters

mc_params = {}

# Number of MC steps used for equilibration
mc_params["mcs_eq"] = 1000

# Number of MC steps used for averaging
mc_params["mcs_av"] = 10

# Type of cooling schedule
# if exponential chosen: specify log10(T) as initial and final temperatures
mc_params["cooling_schedule"] = "exponential"

# Initial annealing temperature
mc_params["Ti"] = 2

# Final annealing temperature
mc_params["Tf"] = 0

# Number of annealing steps
mc_params["Nt"] = 40

# Option to collect state checkpoints at the end of each temperature cycle
mc_params["checkpoint_option"] = True

# If checkpoint is True, we need to provide the output address for the 
# checkpoint files
structures_path = Path("./data/"+run_name+"/structures")
structures_path.mkdir(parents = True, exist_ok = True)

if mc_params["checkpoint_option"]:
    mc_params["checkpoint_address"] = str(structures_path.resolve())+"/"

# Output location of the final state configuration (must end with "/")
mc_params["final_structure_address"] = str(structures_path.resolve())+"/"

make_json_file(mc_params, cfg.input_path/"mc_params.json")

# %%
# Run the simulation from inside the notebook.
# Note that the program only writes to the cell output after it is done running.
# If you want to follow the excecution in real time, run the program from the command line!

# Parameter in run_sim is a boolean flag, which will overwrite the simulation results if set to True

cfg.run_simulation(True)
# Out:
# At least one of the output folders is already populated!
# overwrite flag set to True: running anyway.
# Program runs!
# 5832
# Printing current system state
# Number of particle types: 1
# Number of particles of each type: {200, }
# Printing interactions structure
# Printing coupling matrix: {10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -37.4, 10000, 10000, -18.7, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -37.4, 10000, 10000, 10000, 10000, -18.7, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -18.7, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -18.7, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, -18.7, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -18.7, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -18.7, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -18.7, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, 10000, -18.7, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, 10000, -18.7, 10000, 10000, 10000, 10000, 10000, -37.4, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, 10000, -18.7, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -18.7, -18.7, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -18.7, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -18.7, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -18.7, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, -18.7, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -18.7, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -37.4, 10000, 10000, 10000, 10000, -18.7, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -18.7, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, -18.7, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, -18.7, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -18.7, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, 10000, 10000, -37.4, 10000, 10000, -37.4, 10000, 10000, 10000, 10000, 10000, -18.7, -37.4, 10000, 10000, 1000 ...
# System energy is: 190000
#
# ---------------------------------------------
#       Monte-Carlo simulation parameters
# ---------------------------------------------
#
# Number of equilibration steps mcs_eq = 1000
# Number of averaging steps mcs_av = 10
#
# Initial temperature Ti = 2
# Final temperature Tf = 0
# Number of temperature steps Nt = 40
#
# The selected cooling schedule is exponential
#
# Output location for checkpoints: /Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/examples/cubic/data/01_camembert_test/structures/
#
# Output location for the final structure: /Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/examples/cubic/data/01_camembert_test/structures/
#
# Energy at T = 100: -355.3
#  T = 89.1251: -74.8
# Energy at T = 79.4328: -168.3
# Energy at T = 70.7946: -486.2
# Energy at T = 63.0957: -299.2
# Energy at T = 56.2341: -299.2
# Energy at T = 50.1187: -149.6
# Energy at T = 44.6684: -205.7
# Energy at T = 39.8107: -336.6
# Energy at T = 35.4813: -467.5
# Energy at T = 31.6228: -430.1
# Energy at T = 28.1838: -579.7
# Energy at T = 25.1189: -654.5
# Energy at T = 22.3872: -860.2
# Energy at T = 19.9526: -841.5
# Energy at T = 17.7828: -878.9
# Energy at T = 15.8489: -1458.6
# Energy at T = 14.1254: -2038.3
# Energy at T = 12.5893: -6713.3
# Energy at T = 11.2202: -14361.6
# Energy at T = 10: -16175.5
# Energy at T = 8.91251: -16923.5
# Energy at T = 7.94328: -17035.7
# Energy at T = 7.07946: -17521.9
# Energy at T = 6.30957: -17559.3
# Energy at T = 5.62341: -17578
# Energy at T = 5.01187: -17578
# Energy at T = 4.46684: -17578
# Energy at T = 3.98107: -17578
# Energy at T = 3.54813: -17578
# Energy at T = 3.16228: -17578
# Energy at T = 2.81838: -17578
# Energy at T = 2.51189: -17578
# Energy at T = 2.23872: -17578
# Energy at T = 1.99526: -17578
# Energy at T = 1.77828: -17578
# Energy at T = 1.58489: -17578
# Energy at T = 1.41254: -17578
# Energy at T = 1.25893: -17578
# Energy at T = 1.12202: -17578

# %%
# Plotting module creates a blender file which you have to open yourself

blend_file_path = f"3dFigures/02_camembert_contacts"
if Rplus_flag:
    blend_file_path += "_Rplus"
if Gplus_flag:
    blend_file_path += "_Gplus"
if Bplus_flag:
    blend_file_path += "_Bplus"
if Rminus_flag:
    blend_file_path += "_Rminus"
if Gminus_flag:
    blend_file_path += "_Gminus"
if Bminus_flag:
    blend_file_path += "_Bminus"
blend_file_path += ( f"_crystal_{crystal_energy:.02f}"
f"_rep_{repel_energy:.02f}_defect_{defect_energy:.02f}.blend")

plot_cubes_from_simulation_results(struct_folder = str(structures_path.resolve()), fig_file = blend_file_path)
# Out:
# 200
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# /var/folders/v3/gbqhvbxs6nz1258v43493tx40000gp/T/ipykernel_70733/2060227659.py:21: UserWarning: Gimbal lock detected. Setting third angle to zero since it is not possible to uniquely determine all angles.
#   plot_cubes_from_simulation_results(struct_folder = str(structures_path.resolve()), fig_file = blend_file_path)
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# ...
# OBJ import of 'one_cube_numbered.obj' took 1.22 ms
# OBJ import of 'one_cube_numbered.obj' took 1.31 ms
# OBJ import of 'one_cube_numbered.obj' took 1.29 ms
# OBJ import of 'one_cube_numbered.obj' took 1.50 ms
# OBJ import of 'one_cube_numbered.obj' took 1.79 ms
# OBJ import of 'one_cube_numbered.obj' took 1.67 ms
# OBJ import of 'one_cube_numbered.obj' took 1.29 ms
# OBJ import of 'one_cube_numbered.obj' took 1.47 ms
# OBJ import of 'one_cube_numbered.obj' took 1.53 ms
# OBJ import of 'one_cube_numbered.obj' took 1.32 ms
# OBJ import of 'one_cube_numbered.obj' took 1.72 ms
# OBJ import of 'one_cube_numbered.obj' took 1.62 ms
# OBJ import of 'one_cube_numbered.obj' took 1.43 ms
# OBJ import of 'one_cube_numbered.obj' took 1.28 ms
# OBJ import of 'one_cube_numbered.obj' took 1.32 ms
# OBJ import of 'one_cube_numbered.obj' took 1.27 ms
# OBJ import of 'one_cube_numbered.obj' took 1.19 ms
# OBJ import of 'one_cube_numbered.obj' took 1.69 ms
# OBJ import of 'one_cube_numbered.obj' took 1.52 ms
# OBJ import of 'one_cube_numbered.obj' took 1.40 ms
# OBJ import of 'one_cube_numbered.obj' took 1.24 ms
# OBJ import of 'one_cube_numbered.obj' took 1.39 ms
# OBJ import of 'one_cube_numbered.obj' took 1.64 ms
# OBJ import of 'one_cube_numbered.obj' took 1.33 ms
# OBJ import of 'one_cube_numbered.obj' took 1.62 ms
# OBJ import of 'one_cube_numbered.obj' took 1.32 ms
# OBJ import of 'one_cube_numbered.obj' took 1.25 ms
# OBJ import of 'one_cube_numbered.obj' took 1.26 ms
# OBJ import of 'one_cube_numbered.obj' took 1.39 ms
# OBJ import of 'one_cube_numbered.obj' took 1.28 ms
# OBJ import of 'one_cube_numbered.obj' took 1.28 ms
# OBJ import of 'one_cube_numbered.obj' took 1.31 ms
# OBJ import of 'one_cube_numbered.obj' took 1.37 ms
# OBJ import of 'one_cube_numbered.obj' took 1.32 ms
# OBJ import of 'one_cube_numbered.obj' took 1.30 ms
# OBJ import of 'one_cube_numbered.obj' took 1.27 ms
# OBJ import of 'one_cube_numbered.obj' took 1.42 ms
# OBJ import of 'one_cube_numbered.obj' took 1.37 ms
# OBJ import of 'one_cube_numbered.obj' took 1.31 ms
# OBJ import of 'one_cube_numbered.obj' took 1.52 ms
# OBJ import of 'one_cube_numbered.obj' took 1.44 ms
# OBJ import of 'one_cube_numbered.obj' took 1.26 ms
# OBJ import of 'one_cube_numbered.obj' took 1.42 ms
# OBJ import of 'one_cube_numbered.obj' took 1.21 ms
# OBJ import of 'one_cube_numbered.obj' took 1.29 ms
# OBJ import of 'one_cube_numbered.obj' took 1.27 ms
# OBJ import of 'one_cube_numbered.obj' took 1.44 ms
# OBJ import of 'one_cube_numbered.obj' took 1.90 ms
# OBJ import of 'one_cube_numbered.obj' took 1.26 ms
# OBJ import of 'one_cube_numbered.obj' took 1.31 ms
# OBJ import of 'one_cube_numbered.obj' took 1.17 ms
# OBJ import of 'one_cube_numbered.obj' took 1.58 ms
# OBJ import of 'one_cube_numbered.obj' took 1.48 ms
# OBJ import of 'one_cube_numbered.obj' took 1.32 ms
# OBJ import of 'one_cube_numbered.obj' took 1.59 ms
# OBJ import of 'one_cube_numbered.obj' took 1.62 ms
# OBJ import of 'one_cube_numbered.obj' took 1.27 ms
# OBJ import of 'one_cube_numbered.obj' took 1.58 ms
# OBJ import of 'one_cube_numbered.obj' took 1.49 ms
# OBJ import of 'one_cube_numbered.obj' took 1.36 ms
# OBJ import of 'one_cube_numbered.obj' took 1.24 ms
# OBJ import of 'one_cube_numbered.obj' took 3.01 ms
# OBJ import of 'one_cube_numbered.obj' took 0.55 ms
# OBJ import of 'one_cube_numbered.obj' took 0.57 ms
# OBJ import of 'one_cube_numbered.obj' took 0.36 ms
# OBJ import of 'one_cube_numbered.obj' took 0.46 ms
# OBJ import of 'one_cube_numbered.obj' took 0.34 ms
# OBJ import of 'one_cube_numbered.obj' took 0.46 ms
# OBJ import of 'one_cube_numbered.obj' took 0.52 ms
# OBJ import of 'one_cube_numbered.obj' took 0.37 ms
# OBJ import of 'one_cube_numbered.obj' took 0.74 ms
# OBJ import of 'one_cube_numbered.obj' took 0.48 ms
# OBJ import of 'one_cube_numbered.obj' took 0.54 ms
# OBJ import of 'one_cube_numbered.obj' took 0.38 ms
# OBJ import of 'one_cube_numbered.obj' took 0.46 ms
# OBJ import of 'one_cube_numbered.obj' took 0.85 ms
# OBJ import of 'one_cube_numbered.obj' took 0.79 ms
# OBJ import of 'one_cube_numbered.obj' took 0.44 ms
# OBJ import of 'one_cube_numbered.obj' took 0.76 ms
# OBJ import of 'one_cube_numbered.obj' took 0.46 ms
# OBJ import of 'one_cube_numbered.obj' took 0.59 ms
# OBJ import of 'one_cube_numbered.obj' took 0.60 ms
# OBJ import of 'one_cube_numbered.obj' took 0.66 ms
# OBJ import of 'one_cube_numbered.obj' took 0.63 ms
# OBJ import of 'one_cube_numbered.obj' took 0.53 ms
# OBJ import of 'one_cube_numbered.obj' took 1.02 ms
# OBJ import of 'one_cube_numbered.obj' took 0.93 ms
# OBJ import of 'one_cube_numbered.obj' took 0.56 ms
# OBJ import of 'one_cube_numbered.obj' took 0.94 ms
# OBJ import of 'one_cube_numbered.obj' took 0.70 ms
# OBJ import of 'one_cube_numbered.obj' took 0.60 ms
# OBJ import of 'one_cube_numbered.obj' took 0.63 ms
# OBJ import of 'one_cube_numbered.obj' took 0.57 ms
# OBJ import of 'one_cube_numbered.obj' took 0.46 ms
# OBJ import of 'one_cube_numbered.obj' took 0.73 ms
# OBJ import of 'one_cube_numbered.obj' took 0.45 ms
# OBJ import of 'one_cube_numbered.obj' took 0.50 ms
# OBJ import of 'one_cube_numbered.obj' took 0.51 ms
# OBJ import of 'one_cube_numbered.obj' took 0.46 ms
# OBJ import of 'one_cube_numbered.obj' took 0.52 ms
# OBJ import of 'one_cube_numbered.obj' took 0.61 ms
# OBJ import of 'one_cube_numbered.obj' took 0.71 ms
# OBJ import of 'one_cube_numbered.obj' took 0.92 ms
# OBJ import of 'one_cube_numbered.obj' took 0.70 ms
# OBJ import of 'one_cube_numbered.obj' took 0.58 ms
# OBJ import of 'one_cube_numbered.obj' took 0.50 ms
# OBJ import of 'one_cube_numbered.obj' took 0.59 ms
# OBJ import of 'one_cube_numbered.obj' took 0.48 ms
# OBJ import of 'one_cube_numbered.obj' took 0.52 ms
# OBJ import of 'one_cube_numbered.obj' took 0.82 ms
# OBJ import of 'one_cube_numbered.obj' took 0.64 ms
# OBJ import of 'one_cube_numbered.obj' took 0.50 ms
# OBJ import of 'one_cube_numbered.obj' took 0.43 ms
# OBJ import of 'one_cube_numbered.obj' took 0.55 ms
# OBJ import of 'one_cube_numbered.obj' took 0.48 ms
# OBJ import of 'one_cube_numbered.obj' took 0.65 ms
# OBJ import of 'one_cube_numbered.obj' took 0.95 ms
# OBJ import of 'one_cube_numbered.obj' took 0.86 ms
# OBJ import of 'one_cube_numbered.obj' took 0.75 ms
# OBJ import of 'one_cube_numbered.obj' took 0.61 ms
# OBJ import of 'one_cube_numbered.obj' took 0.72 ms
# OBJ import of 'one_cube_numbered.obj' took 0.65 ms
# OBJ import of 'one_cube_numbered.obj' took 0.56 ms
# OBJ import of 'one_cube_numbered.obj' took 0.70 ms
# OBJ import of 'one_cube_numbered.obj' took 0.59 ms
# OBJ import of 'one_cube_numbered.obj' took 0.53 ms
# OBJ import of 'one_cube_numbered.obj' took 0.59 ms
# OBJ import of 'one_cube_numbered.obj' took 1.02 ms
# OBJ import of 'one_cube_numbered.obj' took 0.95 ms
# OBJ import of 'one_cube_numbered.obj' took 1.05 ms
# OBJ import of 'one_cube_numbered.obj' took 0.57 ms
# OBJ import of 'one_cube_numbered.obj' took 0.93 ms
# OBJ import of 'one_cube_numbered.obj' took 1.02 ms
# OBJ import of 'one_cube_numbered.obj' took 1.01 ms
# OBJ import of 'one_cube_numbered.obj' took 0.69 ms
# OBJ import of 'one_cube_numbered.obj' took 0.60 ms
# OBJ import of 'one_cube_numbered.obj' took 0.62 ms
# OBJ import of 'one_cube_numbered.obj' took 0.96 ms
# OBJ import of 'one_cube_numbered.obj' took 0.99 ms
# OBJ import of 'one_cube_numbered.obj' took 0.75 ms
# OBJ import of 'one_cube_numbered.obj' took 0.61 ms
# OBJ import of 'one_cube_numbered.obj' took 0.72 ms
# OBJ import of 'one_cube_numbered.obj' took 0.87 ms
# OBJ import of 'one_cube_numbered.obj' took 0.80 ms
# OBJ import of 'one_cube_numbered.obj' took 0.76 ms
# OBJ import of 'one_cube_numbered.obj' took 0.78 ms
# OBJ import of 'one_cube_numbered.obj' took 0.84 ms
# OBJ import of 'one_cube_numbered.obj' took 0.73 ms
# OBJ import of 'one_cube_numbered.obj' took 1.05 ms
# OBJ import of 'one_cube_numbered.obj' took 1.14 ms
# OBJ import of 'one_cube_numbered.obj' took 0.88 ms
# OBJ import of 'one_cube_numbered.obj' took 1.37 ms
# OBJ import of 'one_cube_numbered.obj' took 1.45 ms
# OBJ import of 'one_cube_numbered.obj' took 1.21 ms
# OBJ import of 'one_cube_numbered.obj' took 1.76 ms
# OBJ import of 'one_cube_numbered.obj' took 1.58 ms
# OBJ import of 'one_cube_numbered.obj' took 1.41 ms
# OBJ import of 'one_cube_numbered.obj' took 1.60 ms
# OBJ import of 'one_cube_numbered.obj' took 1.30 ms
# OBJ import of 'one_cube_numbered.obj' took 1.68 ms
# OBJ import of 'one_cube_numbered.obj' took 1.24 ms
# OBJ import of 'one_cube_numbered.obj' took 1.28 ms
# OBJ import of 'one_cube_numbered.obj' took 1.59 ms
# OBJ import of 'one_cube_numbered.obj' took 1.54 ms
# OBJ import of 'one_cube_numbered.obj' took 1.69 ms
# OBJ import of 'one_cube_numbered.obj' took 1.67 ms
# OBJ import of 'one_cube_numbered.obj' took 1.46 ms
# OBJ import of 'one_cube_numbered.obj' took 1.45 ms
# OBJ import of 'one_cube_numbered.obj' took 1.33 ms
# OBJ import of 'one_cube_numbered.obj' took 1.26 ms
# OBJ import of 'one_cube_numbered.obj' took 1.32 ms
# OBJ import of 'one_cube_numbered.obj' took 1.65 ms
# OBJ import of 'one_cube_numbered.obj' took 1.64 ms
# OBJ import of 'one_cube_numbered.obj' took 1.29 ms
# OBJ import of 'one_cube_numbered.obj' took 1.30 ms
# OBJ import of 'one_cube_numbered.obj' took 1.63 ms
# OBJ import of 'one_cube_numbered.obj' took 1.63 ms
# OBJ import of 'one_cube_numbered.obj' took 1.35 ms
# OBJ import of 'one_cube_numbered.obj' took 1.37 ms
# OBJ import of 'one_cube_numbered.obj' took 1.46 ms
# OBJ import of 'one_cube_numbered.obj' took 1.63 ms
# OBJ import of 'one_cube_numbered.obj' took 1.81 ms
# OBJ import of 'one_cube_numbered.obj' took 1.49 ms
# OBJ import of 'one_cube_numbered.obj' took 1.37 ms
# OBJ import of 'one_cube_numbered.obj' took 1.45 ms
# OBJ import of 'one_cube_numbered.obj' took 1.25 ms
# OBJ import of 'one_cube_numbered.obj' took 1.62 ms
# OBJ import of 'one_cube_numbered.obj' took 1.46 ms
# OBJ import of 'one_cube_numbered.obj' took 1.71 ms
# OBJ import of 'one_cube_numbered.obj' took 1.55 ms
# OBJ import of 'one_cube_numbered.obj' took 1.66 ms
# OBJ import of 'one_cube_numbered.obj' took 1.52 ms
# OBJ import of 'one_cube_numbered.obj' took 1.63 ms
# OBJ import of 'one_cube_numbered.obj' took 1.56 ms
# OBJ import of 'one_cube_numbered.obj' took 1.77 ms
# OBJ import of 'one_cube_numbered.obj' took 1.39 ms
# OBJ import of 'one_cube_numbered.obj' took 1.36 ms
# OBJ import of 'one_cube_numbered.obj' took 1.58 ms
# OBJ import of 'one_cube_numbered.obj' took 1.71 ms
# OBJ import of 'one_cube_numbered.obj' took 1.45 ms
# OBJ import of 'one_cube_numbered.obj' took 1.35 ms
# OBJ import of 'one_cube_numbered.obj' took 1.71 ms
# OBJ import of 'one_cube_numbered.obj' took 1.71 ms
# OBJ import of 'one_cube_numbered.obj' took 1.67 ms
# OBJ import of 'one_cube_numbered.obj' took 1.55 ms
# OBJ import of 'one_cube_numbered.obj' took 1.35 ms
# OBJ import of 'one_cube_numbered.obj' took 1.34 ms
# OBJ import of 'one_cube_numbered.obj' took 1.31 ms
# OBJ import of 'one_cube_numbered.obj' took 1.37 ms
# OBJ import of 'one_cube_numbered.obj' took 1.64 ms
# OBJ import of 'one_cube_numbered.obj' took 1.49 ms
# OBJ import of 'one_cube_numbered.obj' took 1.57 ms
# OBJ import of 'one_cube_numbered.obj' took 1.56 ms
# OBJ import of 'one_cube_numbered.obj' took 1.81 ms
# OBJ import of 'one_cube_numbered.obj' took 3.18 ms
# OBJ import of 'one_cube_numbered.obj' took 1.77 ms
# OBJ import of 'one_cube_numbered.obj' took 1.67 ms
# OBJ import of 'one_cube_numbered.obj' took 1.59 ms
# OBJ import of 'one_cube_numbered.obj' took 1.39 ms
# OBJ import of 'one_cube_numbered.obj' took 1.77 ms
# OBJ import of 'one_cube_numbered.obj' took 1.43 ms
# OBJ import of 'one_cube_numbered.obj' took 1.67 ms
# OBJ import of 'one_cube_numbered.obj' took 1.36 ms
# OBJ import of 'one_cube_numbered.obj' took 1.68 ms
# OBJ import of 'one_cube_numbered.obj' took 1.37 ms
# OBJ import of 'one_cube_numbered.obj' took 1.50 ms
# OBJ import of 'one_cube_numbered.obj' took 1.74 ms
# OBJ import of 'one_cube_numbered.obj' took 1.60 ms
# OBJ import of 'one_cube_numbered.obj' took 1.40 ms
# OBJ import of 'one_cube_numbered.obj' took 1.70 ms
# OBJ import of 'one_cube_numbered.obj' took 1.54 ms
# OBJ import of 'one_cube_numbered.obj' took 1.38 ms
# OBJ import of 'one_cube_numbered.obj' took 1.55 ms
# OBJ import of 'one_cube_numbered.obj' took 1.76 ms
# OBJ import of 'one_cube_numbered.obj' took 1.23 ms
# OBJ import of 'one_cube_numbered.obj' took 1.41 ms
# OBJ import of 'one_cube_numbered.obj'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Loaded image from: '/Users/vincent/research/projects/23_frustratedSelfAssembly/simulations/2404_frusa_lattice_mc/python/src/plotting/assets/oneCube/full_cube_numbered.png'
# Info: Saved "02_camembert_contacts_Rplus_Gplus_Bplus_Rminus_Gminus_Bminus_crystal_-18.70_rep_10000.00_defect_-37.40.blend"

# %% [markdown]
# Once you have ran the above code, you should open the resulting .blend file in blender and see the results for yourself!
